# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
churn = pd.read_csv(r"C:\Users\jacob\Downloads\DSPR_Data_Sets\Website Data Sets\churn")
churn_train, churn_test = train_test_split(churn, test_size = 0.33, random_state = 7)
churn.shape
# Out:
# (3333, 22)

# %%
churn_train.head(n=5)
# Out:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 1593    KS             105        415  405-1108       yes         no
# 1238    OH             147        415  365-5682       yes        yes
# 1123    VA              11        408  358-6796        no        yes
# 1457    HI             118        415  418-6752        no         no
# 2671    SC             152        408  397-9933        no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 1593              0     273.9        119       46.56  ...       23.68
# 1238             24     219.9        118       37.38  ...       17.72
# 1123             24     131.5         98       22.36  ...       19.57
# 1457              0     133.4        113       22.68  ...       10.29
# 2671              0     140.5         92       23.89  ...       15.88
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
churn_train_counts = churn_train['State'].count()
churn_test_counts = churn_test['State'].value_counts()

# %%
churn_train_counts.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-8a77cc9661e5> in <module>
# ----> 1 churn_train_counts.plot(kind='bar')
#
# AttributeError: 'numpy.int32' object has no attribute 'plot'
